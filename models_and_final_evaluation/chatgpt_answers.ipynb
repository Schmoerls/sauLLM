# %%
# With this Notebook we generated the ChatGpt answers

# %%
yes_no_questions_path = "model_evaluation_questions/questions_25.json"
manual_questions_path = "model_evaluation_questions/manual_questions.json"
correctness_questions_path = "model_evaluation_questions/correctness_questions.json"

manual_and_correctness_prompt = "Bitte beantworte folgende juristische Frage: " # Added to start of question
yes_no_prompt = " Antworte mit 'Ja,' 'Nein,' oder 'Unklar'" # Added to end of question

# %%
from openai import OpenAI
client = OpenAI(
    api_key="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"
)

import json
import re

with open(manual_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [manual_and_correctness_prompt + question for question in json_data]

model_answers = []

for question in questions_withprompt:
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "user",
                "content": question
            }
        ]
    )
    answer = completion.choices[0].message.content
    print(answer)
    model_answers.append(answer)

# Save the dictionary to a JSON file 
with open('generation_results/manual_chat_gpt.json', 'w') as file:
    json.dump(model_answers, file, indent=4)

print("FINISHED MANUAL")


# Correctness Answers Generation
with open(correctness_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [manual_and_correctness_prompt + question for question in json_data]

model_answers = []

for question in questions_withprompt:
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "user",
                "content": question
            }
        ]
    )
    answer = completion.choices[0].message.content
    model_answers.append(answer)

# Save the dictionary to a JSON file
with open('generation_results/correctness_chat_gpt.json', 'w') as file:
    json.dump(model_answers, file, indent=4)

print("FINISHED CORRECTNESS")



# Yes_No Answers Generation
with open(yes_no_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [question + yes_no_prompt for question in json_data]

model_answers = []

for question in questions_withprompt:
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "user",
                "content": question
            }
        ]
    )
    answer = completion.choices[0].message.content
    model_answers.append(answer)

yes_pattern = r'\b([Yy]es|[Jj]a)[.!?]?\b'
no_pattern = r'\b([Nn]o|[Nn]ein)[.!?]?\b'

yes_no_answers = []
for answer in model_answers:
    matches_yes = re.findall(yes_pattern, answer)
    matches_no = re.findall(no_pattern, answer)

    if len(matches_yes) != 0 and len(matches_no) != 0:
        yes_no_answers.append("Unklar")
    elif len(matches_yes) != 0:
        yes_no_answers.append("Ja")
    elif len(matches_no) != 0:
        yes_no_answers.append("Nein")
    else:
        yes_no_answers.append("Unklar")

answers_list = [{"long": longAnswer, "short": shortAnswer} for longAnswer, shortAnswer in zip(model_answers, yes_no_answers)]

# Save the dictionary to a JSON file
with open('generation_results/yes_no_chat_gpt.json', 'w') as file:
    json.dump(answers_list, file, indent=4)
# Out:
# Die Begriffe „Bürgerliches Recht“, „Zivilrecht“ und „Privatrecht“ werden oft synonym verwendet, doch gibt es in der juristischen Terminologie feine Unterschiede.
#
# 1. **Privatrecht**: Dieser Begriff ist der allgemeinste und bezeichnet sämtliche Rechtsnormen, die die Beziehungen zwischen privaten Personen (natürlichen und juristischen) regeln. Das Privatrecht umfasst nicht nur das Bürgerliche Recht, sondern auch spezifische Regelungen, wie Handelsrecht oder Gesellschaftsrecht.
#
# 2. **Bürgerliches Recht**: Das Bürgerliche Recht ist ein Teil des Privatrechts und umfasst die Regelungen, die die rechtlichen Beziehungen zwischen Bürgern betreffen. Es regelt insbesondere Schuldverhältnisse, Eigentum, Familienrecht und Erbrecht. In Deutschland ist das Bürgerliche Gesetzbuch (BGB) die zentrale normative Grundlage.
#
# 3. **Zivilrecht**: Dieser Begriff wird oft synonym mit dem Bürgerlichen Recht verwendet, insbesondere im deutschen Sprachraum. In einigen Kontexten kann Zivilrecht jedoch auch das gesamte Privatrecht umfassen, ähnlich wie der Begriff Privatrecht. Deshalb kann es je nach Kontext Unterschiede in der Verwendung geben.
#
# Zusammenfassend lässt sich sagen, dass während „Bürgerliches Recht“ und „Zivilrecht“ oft verwendet werden, um das gleiche Regelwerk zu beschreiben, „Privatrecht“ den umfassenderen Begriff darstellt, der auch andere Rechtsgebiete einschließt.
# Im Privatrecht hat das subjektive Recht eine zentrale Bedeutung, da es den Individuen spezifische Rechte und Ansprüche verleiht, die sie gegenüber anderen Personen geltend machen können. Subjektive Rechte sind die berechtigten Interessen, die eine Person hat und die durch das Rechtssystem geschützt werden. Sie bilden die Grundlage für die rechtlichen Beziehungen zwischen Bürgern, Unternehmen und anderen rechtlichen Entitäten.
#
# Hier sind einige wichtige Aspekte der Bedeutung subjektiver Rechte im Privatrecht:
#
# 1. **Rechtsansprüche**: Subjektive Rechte ermöglichen es Einzelpersonen, Ansprüche geltend zu machen. Beispielsweise hat ein Käufer ein Recht auf Lieferung der gekauften Ware, und ein Verkäufer hat das Recht auf Bezahlung.
#
# 2. **Schutz von Interessen**: Subjektive Rechte dienen dem Schutz individueller Interessen. Sie ermöglichen es den Betroffenen, ihre eigenen Belange zu verfolgen und vor Verletzungen zu schützen.
#
# 3. **Handlungsfreiheit**: Subjektive Rechte fördern die Handlungsfreiheit der Individuen, indem sie ihnen ermöglichen, Entscheidungen zu treffen und rechtlich bindende Vereinbarungen zu treffen, wie etwa Verträge.
#
# 4. **Rechtsordnung und -sicherheit**: Subjektive Rechte tragen zur Stabilität und Vorhersehbarkeit von rechtlichen Beziehungen bei. Sie schaffen klare Erwartungen und Rahmenbedingungen für das Handeln der Akteure im Privatrecht.
#
# 5. **Rechtsschutz**: Subjektive Rechte garantieren den Zugang zu gerichtlichem Schutz und ermöglichen es den Betroffenen, ihre Rechte vor Gericht durchzusetzen, wenn sie verletzt werden.
#
# Insgesamt bilden subjektive Rechte die Grundlage für das Funktionieren des Privatrechts, da sie die Grundlage für rechtliche Ansprüche und die Durchsetzung von Rechtsnormen darstellen.
# Rechtsfähigkeit bezeichnet die Fähigkeit, Träger von Rechten und Pflichten zu sein. In Deutschland sind alle natürlichen Personen von der Geburt an rechtsfähig, gemäß § 1 des Bürgerlichen Gesetzbuches (BGB). Das bedeutet, dass jeder Mensch, der geboren wird, Rechte erwerben und Verpflichtungen eingehen kann.
#
# Darüber hinaus sind auch juristische Personen rechtsfähig. Dazu zählen beispielsweise:
#
# 1. **Vereine**: Eingetragene Vereine sind juristische Personen und somit rechtsfähig.
# 2. **Gesellschaften**: Kapitalgesellschaften wie die GmbH (Gesellschaft mit beschränkter Haftung) und die AG (Aktiengesellschaft) sind ebenfalls rechtsfähig.
# 3. **Stiftungen**: Stiftungen, die rechtlich anerkannt sind, besitzen ebenfalls Rechtsfähigkeit.
#
# Die Rechtsfähigkeit endet mit dem Tod einer natürlichen Person, während juristische Personen solange rechtsfähig sind, wie sie bestehen und im Handelsregister eingetragen sind oder auf andere Weise anerkannt sind.
# Die Rechtsfähigkeit endet mit dem Tod einer natürlichen Person. In Deutschland ist die Rechtsfähigkeit im Bürgerlichen Gesetzbuch (BGB) geregelt. Nach § 1 BGB erlangt eine Person mit der Geburt Rechtsfähigkeit und verliert diese mit dem Tod.
#
# Es gibt jedoch auch Ausnahmen im Bereich der juristischen Personen, wie z.B. Unternehmen oder Vereine, deren Rechtsfähigkeit mit der Auflösung oder Liquidation endet. In solchen Fällen folgt das Ende der Rechtsfähigkeit den spezifischen Regelungen, die für die jeweilige Rechtsform gelten.
#
# Insgesamt lässt sich also sagen, dass die Rechtsfähigkeit bei natürlichen Personen mit dem Tod und bei juristischen Personen mit der Auflösung endet.
# Die Gesellschaft bürgerlichen Rechts (GbR) ist eine der einfachsten Formen der Personengesellschaft und erlangt unter bestimmten Voraussetzungen die Rechtsfähigkeit. Hier sind die wichtigsten Voraussetzungen, damit eine GbR rechtsfähig ist:
#
# 1. **Gesellschafter**: Eine GbR besteht aus mindestens zwei Personen, die natürlicher oder juristischer Art sein können. Die Gesellschafter müssen sich zusammenschließen, um einen gemeinsamen Zweck zu verfolgen.
#
# 2. **Gesellschaftsvertrag**: Obwohl ein schriftlicher Vertrag nicht zwingend erforderlich ist, sollte ein Gesellschaftsvertrag vorliegen, der die Rechte und Pflichten der Gesellschafter regelt. Ein solcher Vertrag kann auch formlos sein (mündlich oder konkludent).
#
# 3. **Gemeinsamer Zweck**: Die Gesellschafter müssen sich zusammenschließen, um einen bestimmten gemeinsamen Zweck zu verfolgen, der rechtlich zulässig ist. Dies kann sowohl ein wirtschaftlicher Zweck als auch ein ideeller Zweck sein.
#
# 4. **Rechtsfähigkeit**: Die GbR selbst ist nicht rechtsfähig im Sinne der vollen eigenständigen Rechtspersönlichkeit. Sie wird jedoch als rechtsfähig angesehen, soweit es um die Fähigkeit geht, Rechte zu erwerben und Verbindlichkeiten einzugehen. Die Gesellschafter haften grundsätzlich persönlich und gesamtschuldnerisch für die Verbindlichkeiten der GbR.
#
# 5. **Keine gesetzliche Verbotsnorm**: Der Zweck der GbR darf nicht gegen gesetzliche Verbotsnormen verstoßen. Ist der Zweck unzulässig, kann die GbR nicht rechtsfähig sein.
#
# Die GbR kann somit in der Praxis Verträge abschließen, klagen und verklagt werden, auch wenn sie nicht als eigenständige juristische Person (wie eine GmbH oder AG) betrachtet wird. Die Gesellschafter bleiben rechtlich und wirtschaftlich für die Handlungen der GbR verantwortlich.
# Ein Verein ist eine rechtsfähige oder nicht rechtsfähige Zusammenschluss von Personen, die sich freiwillig zusammenschließen, um einen bestimmten gemeinsamen Zweck zu verfolgen. In Deutschland wird der Verein im Bürgerlichen Gesetzbuch (BGB) definiert, insbesondere in den §§ 21 bis 79.
#
# Ein Verein muss folgende Merkmale aufweisen:
#
# 1. **Personenvereinigung**: Ein Verein besteht aus mindestens sieben Mitgliedern (bei nicht rechtsfähigen Vereinen können es auch weniger sein).
#
# 2. **Gemeinsamer Zweck**: Die Mitglieder verfolgen einen gemeinsamen Zweck, der ideeller oder wirtschaftlicher Natur sein kann.
#
# 3. **Eingetragener Verein (e.V.)**: Ein Verein kann in das Vereinsregister eingetragen werden, wodurch er eine eigene Rechtspersönlichkeit erhält.
#
# 4. **Vereinsstatuten**: Der Verein operiert auf Basis von Satzungen, die Grundregeln für die Organisation und Abläufe festlegen.
#
# 5. **Freiwilligkeit**: Der Beitritt zum Verein erfolgt freiwillig, und Mitglieder können in der Regel jederzeit austreten.
#
# Die spezifischen Regeln und Vorschriften für die Gründung und den Betrieb eines Vereins können je nach Land und Rechtsordnung variieren, aber die oben genannten Punkte sind allgemeine Grundzüge, die für viele Systeme gelten.
# Ein Rechtsobjekt ist in der Jurisprudenz ein Gegenstand, der Gegenstand von Rechten und Pflichten sein kann. Es handelt sich dabei um das, worüber eine rechtliche Beziehung besteht, somit um alles, was rechtlich relevant ist. Rechtsobjekte können sowohl körperliche Sachen (wie Grundstücke, Fahrzeuge oder Möbel) als auch unkörperliche Sachen (wie geistiges Eigentum oder Forderungen) sein.
#
# In der Regel werden Rechtsobjekte in zwei Hauptkategorien unterteilt:
#
# 1. **Sachen:** Dazu gehören alle materiellen Gegenstände, die physisch vorhanden sind, wie zum Beispiel Immobilien, Möbel oder auch Tiere. Nach § 90 des BGB (Bürgerliches Gesetzbuch) sind Sachen körperliche Gegenstände.
#
# 2. **Rechte:** Hierunter fallen Ansprüche und geistige Eigentumsrechte, beispielsweise Lizenzen, Urheberrechte oder Forderungen gegenüber Dritten.
#
# Das Konzept der Rechtsobjekte ist zentral für das Verständnis des Sachenrechts und des allgemeinen Zivilrechts, da es die Grundlage für die Zuordnung von Rechten und Pflichten zwischen verschiedenen Akteuren bildet.
# Der Unterschied zwischen absoluten und relativen Rechten liegt in der Art ihrer Wirkung und in den Personen, die von ihnen betroffen sind.
#
# 1. **Absolute Rechte**:
#    - Absolute Rechte sind Rechte, die gegenüber jedermann durchsetzbar sind. Sie gelten gegen alle und ermöglichen es dem Inhaber, Dritte von bestimmten Handlungen abzuhalten oder sie zur Unterlassung zu bewegen.
#    - Ein Beispiel für ein absolutes Recht ist das Eigentum. Der Eigentümer eines Hauses hat das Recht, darüber zu verfügen, es zu nutzen oder andere von dessen Nutzung auszuschließen. Jeder kann darauf hingewiesen werden, dass der Eigentümer das alleinige Recht hat, über sein Eigentum zu entscheiden.
#
# 2. **Relative Rechte**:
#    - Relative Rechte gelten hingegen nur zwischen bestimmten Personen, also in einem bestimmten Rechtsverhältnis. Sie sind, im Gegensatz zu absoluten Rechten, nicht gegen jedermann, sondern nur gegenüber bestimmten Personen durchsetzbar.
#    - Ein klassisches Beispiel für ein relatives Recht ist eine vertragliche Forderung. Wenn A und B einen Vertrag schließen, hat A das Recht, von B eine Zahlung zu verlangen. Dieses Recht gilt nur zwischen A und B; Dritte sind davon nicht betroffen.
#
# Zusammenfassend lässt sich sagen, dass absolute Rechte universelle Geltung gegenüber Dritten haben, während relative Rechte spezifische Verhältnisse zwischen bestimmten Parteien betreffen.
# Der Unterschied zwischen Anspruch und Forderung ist in der juristischen Terminologie von Bedeutung und lässt sich wie folgt erklären:
#
# 1. **Anspruch**:
#    - Ein Anspruch ist das Recht einer Person, von einer anderen Person ein bestimmtes Verhalten zu verlangen. Ansprüche sind in der Regel in Gesetzen, Verträgen oder durch die Rechtsprechung verankert.
#    - Beispiel: Ein Käufer hat einen Anspruch auf Lieferung der gekauften Ware, wenn er diese rechtmäßig bestellt und bezahlt hat.
#
# 2. **Forderung**:
#    - Eine Forderung ist ein konkreter Anspruch auf eine bestimmte Leistung, meist eine Zahlung oder Erbringung einer Dienstleistung. Forderungen sind häufig monetär und können z.B. aus Verträgen, gesetzlichen Bestimmungen oder Delikten resultieren.
#    - Beispiel: Der Betrag, den ein Kunde einem Dienstleister für erbrachte Leistungen schuldet, ist eine Forderung, die aus dem Anspruch auf Zahlung resultiert.
#
# Zusammengefasst kann man sagen: Der Anspruch ist das übergeordnete rechtliche Konzept, das die Möglichkeit beschreibt, eine Leistung zu verlangen, während die Forderung die konkrete wirtschaftliche Dimension dieses Anspruchs darstellt, oft in Form einer Geldsumme. Ein Anspruch kann also Grundlage für eine oder mehrere Forderungen sein.
# In Deutschland wird die Geschäftsfähigkeit durch das Bürgerliche Gesetzbuch (BGB) geregelt. Es gibt verschiedene Stufen der Geschäftsfähigkeit, die vor allem das Alter und die geistige Verfassung einer Person berücksichtigen. Hier sind die Hauptstufen:
#
# 1. **Geschäftsunfähigkeit** (§ 104 BGB): Personen, die das siebte Lebensjahr noch nicht vollendet haben, sind geschäftsunfähig. Das bedeutet, dass sie keine rechtsverbindlichen Geschäfte abschließen können, es sei denn, es handelt sich um rechtlich vorteilhafte Geschäfte. Auch Personen, die aufgrund von Krankheit oder Behinderung nicht in der Lage sind, die Bedeutung ihrer Handlung zu verstehen, gelten als geschäftsunfähig (§ 104 BGB).
#
# 2. **Beschränkte Geschäftsfähigkeit** (§ 104 BGB): Minderjährige, die das siebte Lebensjahr vollendet haben, aber noch nicht 18 Jahre alt sind, sind beschränkt geschäftsfähig. Sie können Verträge nur mit ausdrücklicher Zustimmung (Einwilligung) ihrer Eltern oder gesetzlichen Vertreter abschließen, es sei denn, es handelt sich um einen rechtlich vorteilhaften Vertrag oder um einen Vertrag, der mit eigenen Mitteln geschlossen wird (z.B. Taschengeldparagraph, § 110 BGB).
#
# 3. **Vollgeschäftsfähigkeit** (§ 2 BGB): Personen, die volljährig sind (d.h. das 18. Lebensjahr vollendet haben) und nicht unter einer gesetzlichen Betreuung stehen (§ 1896 BGB), sind voll geschäftsfähig. Sie können eigenständig und ohne Einschränkungen Verträge abschließen.
#
# Zusammenfassend lässt sich sagen, dass die Geschäftsfähigkeit in Deutschland in drei Hauptstufen unterteilt werden kann: geschäftsunfähig, beschränkt geschäftsfähig und voll geschäftsfähig.
# FINISHED MANUAL
# FINISHED CORRECTNESS
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 112
#     109 with open('generation_results/yes_no_chat_gpt.json', 'w') as file:
#     110     json.dump(answers_list, file, indent=4)
# --> 112 if use_logging:
#     113     for question, answer, yes_no_answer in zip(questions_withprompt, model_answers, yes_no_answers):
#     114         print("Frage:")
#
# NameError: name 'use_logging' is not defined
