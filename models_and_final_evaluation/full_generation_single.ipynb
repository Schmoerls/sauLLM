# %%
# Mit diesem Notebook wurde die Generierung aller drei Evaluationsausgaben für einen ausgewählten LoRA Adapter durchgeführt
# RESTART KERNEL BEFORE NEW USAGE
# RESULTS ARE IN /generation_results

yes_no_questions_path = "model_evaluation_questions/questions_25.json"
manual_questions_path = "model_evaluation_questions/manual_questions.json"
correctness_questions_path = "model_evaluation_questions/correctness_questions.json"

use_logging = True
use_base_model = False # Nutzung des mistral base models, wenn true wird der save_name verändert -> mistral_base
lora_to_evaluate = "../fullRun/lorasPlainDataRunBig/checkpoint-3000"
save_name = "plainData-finetuning-3000"

manual_and_correctness_prompt = "Bitte beantworte folgende juristische Frage: " # Added to start of question
yes_no_prompt = " Antworte mit 'Ja,' 'Nein,' oder 'Unklar'" # Added to end of question

# %%
import torch
from huggingface_hub import login, logout
from unsloth import FastLanguageModel
import os
from peft import PeftModel
import json
import re

login("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")
os.environ["WANDB_DISABLED"] = "true"

device = torch.device("cuda")

# Gute Daten vom bisher best-trainierten Model
base_model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/mistral-7b-v0.3", 
    local_files_only = True, 
    max_seq_length = 400, # Choose any! We auto support RoPE Scaling internally!
    dtype = None, # None for auto detection. Float16 "or Tesla T4, V100, Bfloat16 for Ampere+
    load_in_4bit = True, # Use 4bit quantization to reduce memory usage. Can be False.
)
FastLanguageModel.for_inference(base_model)

if use_base_model:
    print("USING MISTRAL BASE")
    peft_model = base_model
    save_name = "mistral_base"
else:
    print("USING LORA: " + lora_to_evaluate)
    peft_model = PeftModel.from_pretrained(base_model, lora_to_evaluate, is_trainable=False) 



# Manual Answers Generation
with open(manual_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [manual_and_correctness_prompt + question for question in json_data]

model_answers = []

for question in questions_withprompt:
    input_ids = tokenizer(question, return_tensors="pt").input_ids
    peft_model_outputs = peft_model.generate(input_ids=input_ids, repetition_penalty=1.4, early_stopping=True, max_new_tokens=400) # top_k=5, top_p=0.9, temperature=0.1,
    cut_tensor = peft_model_outputs[:, input_ids.size(1):]
    peft_model_text_output = tokenizer.decode(cut_tensor[0], skip_special_tokens=True, add_generation_prompt = False)
    model_answers.append(peft_model_text_output)

# Save the dictionary to a JSON file 
with open('generation_results/manual_' + save_name + '.json', 'w') as file:
    json.dump(model_answers, file, indent=4)

if use_logging:
    for question, answer in zip(questions_withprompt, model_answers):
        print("Frage:")
        print(question)
        print("\n Antwort:")
        print(answer)
        print("\n ###########################")
    
print("FINISHED MANUAL")



# Correctness Answers Generation
with open(correctness_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [manual_and_correctness_prompt + question for question in json_data]

model_answers = []

for question in questions_withprompt:
    input_ids = tokenizer(question, return_tensors="pt").input_ids
    peft_model_outputs = peft_model.generate(input_ids=input_ids, repetition_penalty=1.4, early_stopping=True, max_new_tokens=400) # top_k=5, top_p=0.9, temperature=0.1,
    cut_tensor = peft_model_outputs[:, input_ids.size(1):]
    peft_model_text_output = tokenizer.decode(cut_tensor[0], skip_special_tokens=True, add_generation_prompt = False)
    model_answers.append(peft_model_text_output)

# Save the dictionary to a JSON file
with open('generation_results/correctness_' + save_name + '.json', 'w') as file:
    json.dump(model_answers, file, indent=4)

if use_logging:
    for question, answer in zip(questions_withprompt, model_answers):
        print("Frage:")
        print(question)
        print("\n Antwort:")
        print(answer)
        print("\n ###########################")

print("FINISHED CORRECTNESS")



# Yes_No Answers Generation
with open(yes_no_questions_path, 'r') as file:
    json_data = json.load(file)

questions_withprompt = [question + yes_no_prompt for question in json_data]

model_answers = []

for question in questions_withprompt:
    input_ids = tokenizer(question, return_tensors="pt").input_ids
    peft_model_outputs = peft_model.generate(input_ids=input_ids, repetition_penalty=1.4, early_stopping=True, max_new_tokens=400) # top_k=5, top_p=0.9, temperature=0.1,
    cut_tensor = peft_model_outputs[:, input_ids.size(1):]
    peft_model_text_output = tokenizer.decode(cut_tensor[0], skip_special_tokens=True, add_generation_prompt = False)
    model_answers.append(peft_model_text_output)

yes_pattern = r'\b([Yy]es|[Jj]a)[.!?]?\b'
no_pattern = r'\b([Nn]o|[Nn]ein)[.!?]?\b'

yes_no_answers = []
for answer in model_answers:
    matches_yes = re.findall(yes_pattern, answer)
    matches_no = re.findall(no_pattern, answer)

    if len(matches_yes) != 0 and len(matches_no) != 0:
        yes_no_answers.append("Unklar")
    elif len(matches_yes) != 0:
        yes_no_answers.append("Ja")
    elif len(matches_no) != 0:
        yes_no_answers.append("Nein")
    else:
        yes_no_answers.append("Unklar")

answers_list = [{"long": longAnswer, "short": shortAnswer} for longAnswer, shortAnswer in zip(model_answers, yes_no_answers)]

# Save the dictionary to a JSON file
with open('generation_results/yes_no_' + save_name + '.json', 'w') as file:
    json.dump(answers_list, file, indent=4)
    
if use_logging:
    for question, answer, yes_no_answer in zip(questions_withprompt, model_answers, yes_no_answers):
        print("Frage:")
        print(question)
        print("\n Antwort:")
        print(answer)
        print("\n YES_NO:")
        print(yes_no_answer)
        print("\n ###########################")

print("FINISHED YES_NO")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/ps2024/.cache/huggingface/token
# Login successful
# ==((====))==  Unsloth 2024.9.post4: Fast Mistral patching. Transformers = 4.45.1.
#    \\   /|    GPU: Quadro RTX 6000. Max memory: 23.462 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.1. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# USING LORA: ../fullRun/lorasPlainDataRunBig/checkpoint-3000
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Frage:
# Bitte beantworte folgende juristische Frage: Bedeuten „Bürgerliches Recht“, „Zivilrecht“ und „Privatrecht“ dasselbe oder bestehen Unterschiede?
#
#  Antwort:
#
#
# Die Entscheidung ist nicht anfechtbar. Die Beschwerde wird zurückgewiesen. 1) Der Antragsteller wendet sich mit seiner sofortigen Beschwerde gegen die Versagung von Prozesskostenhilfebewilligung durch den angefochtenen Beschluss des Amtsgerichts - Familiengerichte in Halle (Saale). Das Verwaltungsamt für Soziales, Jugend-und Bildungswesen hat dem Antragsgegner am XX.XX.2018 eine Unterhaltsverpflichtung auferlegt; der Antragsgegenstand betrifft das Kind A., geboren XXXX, verheiratet seit X.XXXX mit Frau Y.. Mit Schreiben vom XX.XX.2019 beantragt er bei Gericht die Bewilligung von PKH unter Beiordnung seines Bevollmächtigten zur Durchsetzung einer Zahlungenspflicht aus einem Urteil im Wege eines Vaterschaftsanerkenntnisses nach § 36 Absatz 4 SGB XII iVm Artikel 5 EGRL 7/2007 sowie aufgrund eines gerügten Mangels beim Ausgleich zwischen ihm als Arbeitnehmer und seinem Arbeitgeber. Er tritt insoweit vor allem darauf hinweis, dass es zu keinerlei Kontakt zum Kind gegeben habe. Es sei auch keine Pflegezeit gewährt worden. Im Übrigen werde ein weiterer Sohn vorgehalten, welcher ebenfalls einen Titel benötige. Nachdem das zuständigkeitsbegründete Amtsgericht zunächst seine Zulassung abgelehnt hatte, weil diesbezüglich nur noch über seinen Wohnort entsch
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Bedeutung hat das subjektive Recht im Privatrecht?
#
#  Antwort:
# Die Entscheidungsfragen sind in der Prüfung zu behandeln. 1.) Wie ist die Auslegung des § 249 Absatz 3 Satz 1 Nr. 5 StGB vorzunehmen, wenn ein Mittäter sich nicht auf Notwehr berufen kann und er den Töteten auch keinen Schaden zugerechnet haben soll (vgl. OLG Frankfurt am Main NStZ-RR 06/87)? a) Der Angeklagten wird vorgehalten, dass sie ihren Ehemann getötet habe; b) Sie sei mit dem Opfer verrückt gewesen; c) Es handele es um einen Fall von Verlustvermögensschutz oder d) Um eine Versicherungsfälleinheit. 2.) Was bedarf zur Bejahung eines besonders schwerer Raubes nach §§ 249a ff., 250b StGB einer konkreten Gefahr für Leib und Leben des Geschädigten bzw. dessen Familienangehöriger durch den Angreifer selbst ? a) Eine solche Konkretisierung muss nur dann gegeben sein, wenn diese Voraussetzung ausnahmsweise fehlgeschlagen wäre; b) Ein Haftversprechen genügend aber keine Zusichnung über die Freilassung bei Erreichung bestimmter Bedingungen; c) Das Gericht darf davon ausgehen, dass jeder Straftatrichter seine eigene Definition anlegt.
#
# ## Aufgabe I.:
# Welches Tatbestandsmerkmal stellt „die Herbeiführung“ iSd. § 249a Abs. 1 Alt. 2 StGB dar?
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wer ist rechtsfähig?
#
#  Antwort:
# Die Rechtspersönlichkeit des Menschen ergibt sich aus dem Grundgesetz. Das gilt auch für die in Art 1 Absatz 2 GG genannten Personen, wie zB den Staaten und Gemeinden (vgl BVerfGE 35, 40). Der Gesetzesbegriff im Sinne von §§ 78 ff RVG umfasst alle gesamtrechte Normen mit Ausnahme der Verwaltungs-und Strafrechnung sowie solche Vorschriften, deren Anwendbarkeitsbereich nicht auf das öffentliche Interesse beschränkt oder durch eine besondere Zuständigkeit begrenzt wird; dies sind insbesondere Regelungen über die Wahrnehmung privatrechtlicher Aufträge bzw. Geschäftsverhältnisse (BGHZ 69, 105 = NJW 1976, 105 ; vgl OLGR Köln 1999, 105 ). Nach Auffassung des Bundesgerichtshofs kann ein Unternehmen als „Person“ iSd. §§ 78 ff RVG anzusehen sein, wenn es nach seinem Wesenscharakter selbstständige Entscheidungen treffen darf und diese unter eigener Haftung trifft (OLGR München 1999, 105 ) . Eine andere Meinung hingegen sieht einen Betrieb nur dann als Person gemäß §§ 78 ff RVG an, wenn seine Organe eigenständiges Handeln vornehmen können (Kroiß/Pickering , RVG, Kommentar, Stand Juni 2000, § 78 Rdn. 1) . Für die
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wann endet die Rechtsfähigkeit?
#
#  Antwort:
# 1. Die Antragstellerin ist eine Gesellschaft mit beschränkter Haftung, deren Sitz in der Bundesrepublik Deutschland liegt und nach dem Handelsregister des Amtsgerichts A-Stadt unter HRB … eingetragen ist (Anlage K2). Sie betätigt sich im Bereich von Telekommunikationsdienstleistungen für Unternehmen sowie Privatpersonen auf nationaler Ebene. Der Geschäftsbereich umfasst insbesondere den Vertrieb und Betrieb eines Mobilfunksystems einschließlich Internetzugangsdiensten über das Netzwerk einer anderen deutschen GmbH als auch Datenübermittlungsverträge zwischen dieser GmbH und ihren eigenen Abnehmern. Das operative Tagesgeschäft wird durch ein Joint Venture namens B… AG geführt; dieses hat seinen Sitz ebenfalls in Stadt1. Es besteht aus zwei gleichberechtigten Partnergesellschaften – einem US-amerikanischen Konzerngeschäftsfeldunternehmen und der Antragstellerin selbst –, wobei letztgenannte alleineiger Inhaberin aller Kommanditanteile an diesem JV ist. Im Rahmen ihrer Vergütung erhält sie einen jährlichen Zahlbetrag i.S.v. § 305 c Absatz 4 Nr. 6 BGB. Diesem sind keine weiteren Leistungen gegenübergestellt oder vereinbarte Nutzungsgebühren zu entrichten. Für ihre Aufwendungen muss sie jedoch sämtliche Auslagen tragen. Nachdem es ihr nicht gelungen war, diese Vereinbarung zumindest teilweise abzuändern bzw. geltend gemachte Schadensersatzansprüche wegen unred
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Voraussetzungen muss die GbR erfüllen, um rechtsfähig zu sein?
#
#  Antwort:
# Die Rechtsprechung des BGH (Urteil vom 15.03.2006 - II ZB 4/98) ist nicht einschränkend auszulegen und kann auch auf den vorliegenden Fall angewandt werden. Der Gesetzgeber hat mit der Einführung von § 705a Absatz 1 Satz 1 Nrn. 1 bis 3 BGB eine Regelung geschaffen, nach welchen ein Unternehmen als Gemeinschaftsunternehmensgesellschaft in Form einer oHG oder eines KGaA nur dann gegründet wird, wenn es durch einen Vertrag zwischen mehreren natürlichen Personen gebildet wurde; dies gilt unabhängig davon ob das gemeinsame Eigentum am Grundstück im Wege der Erbbau- bzw. Stiftungsverträge übernommen worden war oder aber wie hier unmittelbar vererbt worden ist. Eine Ausnahme gelten danach lediglich für solches Vermögens, dass dem Nachlass zusteht und dessen Überweisung zur Gründung eines Gemeinschaftsunternehmens gesetzt worden ist. Dieses widerspricht jedoch einem allgemeinen Willen des Gesetzgebers, wonach allein bei Anwendung dieser Vorschrift keine Mischform entstehen soll. Es liegt daher nahe, diese Entscheidung des Bundesgerichthofs entsprechend heranzuziehen.
#
# ### Beratungshilfeanfragen können sich grundlegender Natur sind! Wir freuen uns Ihre Hilfsbedarftasachen bearbeiten zu dürfen. Hierzu haben wir zwei verschiedene Modelle bereit gestellt: Das erste Konzept biet
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wie definiert sich der Verein?
#
#  Antwort:
# Die Rechtsfragen sind in den Anlagen 1 und 2 enthalten.
#
# Die Entscheidung ist nicht anfechtbar. Der Beschluss wird am Ende des Verfahrens verkündet, die Beratungsunterlage dem Vorsitzenden übergeben sowie das Protokoll unterzeichnet (§ 30 Absatz 4 Satz 5 GWB). I. Mit Schreiben vom heutigen Tage hat eine Partei beantragt festzustellen, dass sie ein „Verein“ im Sinne von § 7 BGB sei. II. Nach Auffassung des Senats handelt es sich bei dieser Beanstandung um einen unbegründeten Einwand iSd. § 86a ZPO bzw. eines reinen Auskunftsantrags nach § 9 UWG aF oder einer vergleichbaren Regelungen wie z.B. § 10 UKlaG. III. Eine Kostenentscheidung war gemäß Nrn. IV-VI RPflG/RPflGRZKO zu treffen; insoweit gilt Folgendes: - Bei einem ausdrücklichen Klagverbot kann keinerlei Streitgegenstand bestehen. In diesem Fall kommt weder eine Hauptsache noch eine Nebenforderung als streitig vor. Es fehlt auch für diese Fälle jeglicher Grund dafür, aufgrund dessen man etwas anderes entschieden hätte. Daher bedarf es hierzu keine weiteren Erörterungen. Dieser Umstand führt dazu, dass grundsätzlich nur Gebührenpauschalen angefallen sein können. Diese Pauschale beträgt € 10,- pro Stunde. Sie m
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist ein Rechtsobjekt?
#
#  Antwort:
#
#
# Die Entscheidung des Gerichts ergeht kostenfrei. Die Kostentragungsverpflichtungen der Parteien bleiben unberührt, soweit sie nicht durch die gerichtliche Kostenentscheidung berührt sind (§ 10 Absatz 2 Satz 3 GKG). Der Streithilfeantrag wird zurückgewiesen. Das Verfahren über den Anspruch auf Erlass einer einstweiligen Regelung gegenüber dem Land Hessen als Träger öffentlicher Aufgaben gemäß § 64 VwGO richtet sich nach Landesrecht und unterliegt daher auch insoweit keiner Zuständigkeitsregulierung im Sinne von Artikel 5 Nrn. 7 bis 9 EGBL-Verordnung oder inhaltlichen Beschränkungen wegen eines fehlenden Gemeinschaftszusammenhanges iSdArtikels 8a EuV; vgl. Bayerischer VGH vom 16. Juni 2016 – 2 CS 16.100 - juris Rz. 1 f.; OVG Lübeck vom 16. Januar 2018 – 1 MN 1/17 - n.v., jeweils m. w . N.. Im Übrigen gilt für das vorliegend zu entscheidende Behördenstreitschriftenverfahren mit einem ausländischen Staat bzw. dessen Vertreterin keine andere Bewertung. Es handelt es sich um eine internationale Konfliktbeilegung zwischen zwei Staaten, bei denen jede Seite ihre nationale Gesetzgebungsmacht heranziehen kann. Dieser Umstand steht zwar grund
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist der Unterschied zwischen absoluten und relativen Rechten?
#
#  Antwort:
# Die Anforderungen an die Begründung einer Entscheidungsfragen sind in § 12 Abs. 3 Satz 4 VwGO geregelt, wonach sie sich nach den Grundsätzen des Zivilprozesses richten sollten (vgl.: OVG Berlin-Brandenburg, Beschluss vom 09. Februar 2017 – OVG 5 N 68/16 –, juris Rn. 1). Danach muss eine klare Formulierung enthalten sein; es genügt nicht ein bloßer Hinweis auf einen Sachverhalt oder das Vorliegen eines bestimmten Tatbestandes sowie dessen Auslegung durch Gerichte oder Verwaltungsträger. Der Beitrag zur Lehre kann auch aus einem Fallstudie bestehen, sofern diese hinreichend konkret beschrieben wird. Eine reine Wiedergabe von Literaturstellen ohne eigene Auseinandersetzung mit dem Gegenstand stellt dagegen keinen sinnvolle Beitrag dar. Zur Erläuterung können zwar allgemeiner Sprache bedürftige Begriffe verwendet werden, jedoch nur dann, wenn dies für jedermann erklärbar erscheint. Es kommt keine ungeprähte Aufzeigung diverser Quellentexte vor. Auch bei mehreren Antwortmöglichkeiten hat jeder Teilnehmer seine eigenständigen Überzeugungen zu formulieren bzw. deren Argumentation schlüssig zusammenzufassen. Dies setzt grundsätzlich mindestens zwei Paragraphe pro Seite voraus. Einzelne Punkte lässt man aber im Rahmen dieser Regel außer Betracht, um insbesondere kurzes Text
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist der Unterschied zwischen Anspruch und Forderung?
#
#  Antwort:
#
#
# Ansprüche sind Rechte, die dem Gläubiger gegen den Schuldner zustehen. Sie können sich aus einem Vertrag oder einer gesetzlichen Regelung ergeben (vgl.: BGHZ 189,205). Die Auszahlungsansprüche des Arbeitnehmers auf Lohn/Gehalt sowie Urlaubsabgeltungen stellen Beispielsfälle für solcher Ansprüche dar. Deren Gegenstand kann auch ein Geldbetrag sein; dieses wird dann als „Forderung“ bezeichnet. Einzelne Teile eines Gesamtbetrages werden ebenfalls mit diesem Terminus beschrieben. So spricht man von Teilforderungen bei mehreren gleichzeitig geltend gemachten Beträgen wie etwa Mehrarbeitsvergütung neben Gehalts- bzw. Arbeitsentgelterhöhungen etc.. Auch in anderen Bereichen findet dieser Sprachgebrauch statt – so im Zivilrecht über das Wortschatzbuch hinausgehend -, wenn es um einen bestimmten Geldsaldo geht. Insofern handeln wir nicht nur vom Grundwortlaut her, sondern auch nach Sinn und Zweck, nämlich dass eine Forderung immer zu verstehen ist als konkreterer Bestandteil eines größeren Saldes an Leistungen, also insbesondere zur Abgrenzung zum Restbestand anderweitigen Vorgangs. Dies hat seine Ursache vor allem dadurch, dass gerade beim Streit um Entlohnungssätze regelmäßige Abrechnungen vorgelegt werden müssen, wobei diese jeweils lediglich Abschnittsbestände enthalten. Es kommt daher häufig dazu, dass verschied
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wer ist geschäftsfähig? Gibt es verschiedene Stufen der Geschäftsfähigkeit?
#
#  Antwort:
# Wie kann man die Geschäftsunfähigkeit eines Menschen feststellen und wie lange muss eine Person in diesem Zustand sein, um als nicht mehr geschäfts- oder rechtsunfähig anzusehen. Die Entscheidung des Gerichtes über den Erlass einer einstweiligen Anordnung nach § 12 Abs 3 Satz 4 VormünderG (juris) richtet sich danach, ob das Vorliegen von Tatsachen glaubhaft gemacht worden sind, aus denen aufgrund vernünftiger Betrachtungsweise mit hinreichend großer Gewissheit zu schlussfolgern wäre, dass dem Mündel im Zeitpunkt seiner Einwilligungserklärungen seine Fassung fehlt bzw. er zur Abgabe dieser Erklärungen gezwungen wurde; dies gilt auch dann, wenn diese Annahme nur für einen Teilbereich gelten sollte.(Rn.50)
#
# Die Beschwerde wird zurückgewiesen. Der Verfahrenswert beträgt bis zum 8. Juni 2017 € 690,- ab Rechtshängigkeit am selben Tag € 1.380.-. I. Mit ihrer sofortigen Beschwerde gegen den ihr am 10. Mai 2017 zugestellten Beschluß vom gleichen Datum will die Beteiligte zu 1), deren Aufenthaltsort unbekannt war, ihre vorläufige Unterbringung erreichen. Sie hat ihren Willen durch Schreiben ihres Prozessbevollmächtigten vom 10. April 2017 angezeigt. Das Amtsgericht - Nachlassgericht - Kob
#
#  ###########################
# FINISHED MANUAL
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Unterschiede bestehen zwischen der Abgabe einer Willenserklärung durch einen Geschäftsunfähigen und durch einen beschränkt Geschäftsfähigen?
#
#  Antwort:
# Die Entscheidungen des BGH vom 10. Juni 2008 (VIII ZR 34/07) sowie diejenige des OLGR Hamburg, Beschluss v. 9. April 2006 - Az.: 5 Wx 1/06- sind nicht einschlägig. Der Antrag auf Bewilligung von Prozesskostenhilfe für das Berufungsverfahren wird zurückgewiesen. I. Das Amtsgericht hat mit Urteil vom 10. Januar 2012 den Kläger verurteilt, an die Beklagten zu zahlen € 1.000,- nebst Zinsen in Höhe von fünf Prozentpunkten über dem Basiszinssatz seit Rechtshängigkeit. Gegen dieses am 23. Februar 2012 zugestellte Urteil wendet sich der Kläger mit seiner form-und fristsgemäß eingelegten sofortigen Beschwerde. Er beantragen erneut unter Aufrechterhaltung seines erstinstanzlichen Vortrags, die Beklagten zur Rückzahlung eines Betrages i. H.v. € 1.000.- nebst Zinsen aus einem Darlehensvertrag Nr...... . Zur Begründung trägt er vor, dass es ihm im Zeitraum ab Oktober bis Dezember 2009 um eine finanziellen Hilfen gegangen sei; da seine Einkünfte nur ca. DM 1.000,- beträgen hätten, habe man ihn dazu gedrückt, ein Kredit bei der Bank A AG zu schließen. Dieser Vergleich werde bestätigt dadurch, dass auch
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Kann ein Elternteil allein die Zustimmung zu einem Rechtsgeschäft des Minderjährigen erteilen?
#
#  Antwort:
# Die Entscheidungsfindung ist nicht nur auf den Wohl der Kinder, sondern auch darauf gerichtet, dass sie in einer für das Kind günstigsten Weise ausgestaltet wird. Das bedeutet aber noch mehr als eine bloße Berücksichtigung von Interessen und Belangen eines jeden Einzelnen (vgl.: BGHZ 189, 205). Der Gesetzgeber hat mit dem SGB VIII bewusst davon abgesehen, einen gesamten Teilbereich - wie etwa die Erbringungen im Rahmen sozialer Leistungen oder Unterhaltspflichten - ausschließlich unter Aufgaben- bzw. Verwaltungsverhältnissen zur Regel zu stellen; vielmehr soll es bei diesbezüglichen Ansprüchen weiterhin um individuelle Beziehungsgrundlagen geht (BVerfGE 76, 34/35 f.). Dieses Grundprinzip muss sich nach Auffassung des Senats auch dann durchsetzen lassen, wenn über die Auswahl zwischen verschiedenen Alternativen entschieden werden muss. Denn selbst wenn man zugunsten des Jugendamtsempfehlens annehmen wollte, dass diese grundlegender sei als andere Vorschläge, hätte doch gleichwohl jeder Betroffene sein eigenes Meinungsbild entwickeln können und dürfte daher seine eigentliche Vorstellung vertreten möchten haben. Es kann also keinesfalls ohne weitere Präzisierung feststehen, ob hierzu lediglich diejenige Person berechtigt war, deren Willen vom Gericht berücksichtigt wurde. Eine solche Einschränkung könnte allerdings vorlie
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Kann die Willenserklärung eines Geisteskranken ausnahmsweise voll wirksam sein?
#
#  Antwort:
# Die Entscheidungsformel lautet wie folgt: 1. Der Beklagten wird es bei Meidungen einer Ordnungsgeldandrohung von bis zu EUR 250,00 für jedes einzelne Verstoß gegen diese Anordnung untersagt, im geschäftlichen oder sonstigen Zusammenhang mit der Erbringung und/oder Vermittlung medizinischer Leistungen in Deutschland als „Dr.“ vorzunehmen; insbesondere ist ihr verboten, sich selbst so bezeichnete Doktorgrad („Drs“) nachzuweisen bzw. diesbezüglich eine entsprechende Urkunde zur Vorlage an den Patienten bereitzuhalten sowie auf dem Internet unter www.(…).de einen Profil-Auftragsblatt entgegenzustellen, das sie als Dr. ….. vorgibt. Im Übrigens bleiben alle weiterhin bestehenden Unterlassungsansprüchen des Klägers unberührt. Das Versäumnisurteil vom 30. Juni 2016 – Az.: OLG Frankfurt am Main - 4 UF 78/16 – wird bestätigt. Von den Gerichtskosten hat jeder Partei jeweils Hälfte zu tragen. Außergerichtliche Auslagen werden nicht erstattet. Beschluss Der Streitwert beträgt € 9.000,-. I.) Mit Schreiben seines Bevollmächtigten vom 15. Februar 2016 machte der Kläger geltend, dass er durch die Bezeichnung seiner Gegnerin als "Dr." gemäß §§ 3 Absatz 1 Nr. 1, 5a Absatz 1 S
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Kann ein Minderjähriger ohne Einwilligung des gesetzlichen Vertreters einen wirksamen gegenseitig verpflichtenden Vertrag schließen? Wie ist es bei einseitig den anderen Teil verpflichtenden Verträgen? Kann der Minderjährige wirksam ein Buch entleihen?
#
#  Antwort:
# Die Entscheidung ergeht gerichtsgebührenfrei.
#
# Die Klägerin macht gegen die Beklagten Ansprüche aus einem von ihr abgeschlossenen Leihbuchverhältnis geltend, das sie als Kind unterzeichnet hat und mit dem sich auch eine Rückzahlungs- bzw. Schadensersatzansprüchen wegen einer nicht zurückgelangten Ausgabe gelöschter Seiten in Höhe von insgesamt ca. €105.238,- (Klageantrag zu Ziffer I.) sowie weitere Nebenkosten für Rechtsdienstleister zur Durchsetzung dieser Forderungen stützt (Ziff II.). Sie behauptet hierzu, dass ihre Eltern im Jahr … nach ihrem Geburt am XX.XX.….. geboren worden seien; diese hätten bereits seit ihrer ersten Lebenszeit bis zum Zeitpunkt des Abschlusses eines Erbengemeinschaftsabkommens vom XXXX.XXXX durch Notar A., UR Nr.: .../... über alle Vermögenswerte zwischen ihren beiden Töchtern geteilt gehabt. Der Vater sei zudem schon vorher an verschiedene Schulden betroffen gewesen, so dass seine Einkünfte nur noch knapp genügten um seinen eigenen Unterhalt aufzubringen. Dieser habe daher keine Geldreserven mehr besessen, wodurch ihm keinerlei Mittel zur Finanzierung oder Abdeckung etwaigen Risikos offengebliebenn waren. Auch wenn man davon ausgegangen werde, dass die Kinder jahrelange Jahre lang gemeinsame Haushaltsführung praktiziert haben sollten, könne dies aber letztlich dazu führen
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was versteht man unter einem für den Minderjährigen neutralen Geschäft? Ist dieses wirksam?
#
#  Antwort:
# 1. Die Klägerin ist die Tochter des Beklagten zu 2). Sie hat mit der am ….., eingegangenen und dem Beklagten zu 3) zugestellten Klageschrift einen Anspruchsausgleichsanspruch aus § 80 Absatz 4 Satz 5 ZPO geltend gemacht. Der Beklagte zu 3), ein Rechtsanwalt in Hamburg, hatte im Jahr 2009 eine Kostenlast von ca. € 67.000,- gegenüber seinem Mandanten (Beklagter zu 2)) abzurechnen. Dieser war seinerseits Prokurist bei einer GmbH gewesen; diese Gesellschaft wurde insolvent. Das Insolvenzeröffnungsverfahren über das Vermögen dieser Firma ging aufgrund eines Beschlusses vom ..... vor dem Amtsgericht H., Az.: .../.... Mit Schreiben seines jetzigen Verfahrensbevollmächtigten an Herrn Dr. R..., datiert vom ............., beantragt er nunmehr beim AG H.-Stadt-Außenvorort - Einzelrichter -, dass ihm als Schuldnervertretern bestellt wird. In diesem Schriftsatz heißt es weiterhin ua.: „Der Gläubiger muss sich nicht darauf berufen können, dass sein Vorschlagsrecht nach §§ 1 ff IInsO entfallen sei.“ Im Rahmen dessen forderte der Beklagte zu 3) seinen Auftrager zur Abgabe einer Unterwerftungserklärung sowie zum Ausweis aller Kontoguthaben auf. Nachdem auch hier keine Erfolge erreichten wurden, wandte
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was versteht man unter einem beschränkten Generalkonsens?
#
#  Antwort:
# Die Entscheidung des Bundesverfassungsgerichts vom 18.03.2020 (Az.: BVerfG, Kammerbeschluss - Beschlussempfehlungen der Antragstellerin und Beigeladenen zu 4) ist nicht anzufechtendes Recht im Sinne von § 57 Absatz 6 VwGO oder nach dem Gesetz über die Zulässigkeit einer Nebenintervention in Verwaltungsstreitsachen ein zugrunde liegendes Urteil iSd. §§ 91a Satz 1 Nrn. 1 bis 3 GWB; es kann auch keinen anderen Inhalt haben als eine rechtskräftige gerichte Entscheidung gemäß den genannten Normen. Der Senat hat mit Schreiben seines Berichterstatters vom heutigen Tattag das Vorliegen eines Falles ausgeschlossener Sachaufklärung geprüft und festgestellt, dass keine weitergehenden Ermittlungsergebnisse erwartet werden können.
#
# Die Kostenentscheidung beruhe auf § 154 Absätze 1 und 2 VwGO sowie § 100 Absatz 1 Halbsatz 1 ArbnO. Eine Streitwertfestsetzung findet wegen der gesamtschuldnerischen Haftung statt.
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was versteht man unter Einwilligung und Genehmigung?
#
#  Antwort:
# Die Entscheidung des Gerichts ist rechtskräftig. 1.) Der Antrag der Klägerin auf Bewilligung von Prozesskostenhilfe für das Berufungsverfahren wird zurückgewiesen, weil die Rechtssache keine hinreichende Aussicht bietet (§ 166 Variante 2 ZPO). Das Landgericht hat den Beklagten zu 3) mit Urteil vom 09. Mai 2018 zur Auszahlung eines Betrages in Höhe von € 457,-- an die Klägerin sowie zum Erlass einer entsprechenden Unterwerftungserklärung gegenüber dem Finanzamt verurteilt; im Übrigen wurde die Klage ab-weisen. Gegen dieses am 16. Juni 2018 zugestellte Urteil wendet sich die Klägerin mit ihrer form-und fristgerechten sofortigen Beschwerde. Sie macht geltend, dass sie nicht über eine ausreichende Vergleichsmasse verfüge, um einen Teilbetrag ihres Schadensersatzanspruches bezahlen zu können. Dieser Umstand sei bereits bei Vorlage der Kostenvoranmeldungen durch ihren damaligen Prozeßbevollmächtigten erkannt worden. Im Hinblick darauf habe dieser ihr auch empfohlen, ein weiteres Mandat beim Oberlandesgericht Hamburg als Nebenintervenientin einzuholen. Eine solche Möglichkeit bestehe jedoch nur dann, wenn es vorliegen könne, dass „die Partei“ - also hier die Klägerin selbst – ihre eigenen Interessen schützen werde bzw.,
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was passiert, wenn ein beschränkt Geschäftsfähiger ein einseitiges Rechtsgeschäft vornimmt?
#
#  Antwort:
# Die Entscheidung ist nicht anfechtbar. 1.) Der Antrag des Schuldners auf Eröffnung eines Insolvenzverfahrens über sein Vermögen wird zurückgewiesen. Das Verfahren wurde durch den Beschluss vom heutigen Tage eingestellt und das Aktenzeichen gelöscht (§ 2 Absatz 4 Satz 3 Nr. 5 GVG). Zur Begründung der Einstellungsentscheidung hat die Kammer in dem angefochtenen Beschluss ausgeführt: „Der Senat hält es für sachgerecht, von einer Fortsetzung abzusehen; eine weitere Sachaufklärung würde keine neuen Umstände ergeben.“ Dieser Hinweis war ausreichend, um einen weitergehenden Vortrag zu vermeiden. Nachdem sich im Rahmen dieser Prüfläufe herausgestellt hatte, dass keinerlei neue Gesichtspunkte vorgetragen werden konnten oder ersichtlich waren, so kam auch nach Aufforderungen zur Stellungnahme seitens Gerichtes nur noch schlichte Wiederholung aller bisher gehaltenen Ausführungen mit Nennung bereits bekannter Daten statt. Auch unter Berücksichtigung dieses Umstandes kann aber doch davon gesprochen werden, dass alle relevanten Aspekte nun endgültig geklärt sind bzw. zumindest bekannt gewesen seien. Es handelt sich hierbei insbesondere darum, ob tatsächliche Indizien dafür bestehen könnte, dass der Schuldner bei Abgabe seiner Unterlagen bewusste Unrichtigkeit angab. Hierzu haben sowohl der Gläubiger als auch seine Proz
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Tatbestandsmerkmale müssen für eine Willenserklärung vorliegen?
#
#  Antwort:
# Die Entscheidungsfindungen des Gerichts sind nicht verbindlich. 1.) Der Antragsteller ist ein Verein, der sich mit dem Ziel betätigt, die Rechte von Minderheiten in Deutschland zu schützen und sie gegen Diskriminierungen wehrt. Er hat seinen Sitz im Land A-Stadt (im Folgenden „Antragsgegner“). In seinem Aufbauprogramm heißt es unter anderem: „Der ANTRAGSTELLER setzt seine Arbeit auf den Gebieten Gleichbehandlung sowie Verhältnismäßigkeit um.“ Im Jahr 2019 erstellten Mitglieder des Vereins einen Bericht über das Thema „Gleiches Alter – gleiches Arbeitsverhalten“, welcher am 30. Januar 2020 als Pressemitteilung öffentlich zugänglich gemacht wurde. Daraus geht hervor, dass Frauen bis zum Rente hätten arbeiten sollen; dies sei auch gesetzliche Pflicht gewesen. Das Bundesministerium für Familie, Senioren, Gesundheit, Jugend und Versorgung habe darauf bestanden, dass alle Menschen gleichermaßen lange leben würden wie heute. Dieser Wunsch werde durch die Lebensversicherung realisiert. Es bestehen aber Zweifel an deren Effektivität. So könne man bei einer Lebenserwartung von nur noch ca. 85 Jahren keine Vorsorge treffen. Auch seien viele Leute schon jetzt altersbedingt ausgeschieden oder gar gestorben. Deshalb bietet der ANTRAGSGEGENGER nunmehr eine neue Form der Pensionierung an, nämlich ab einem Alter zwischen 64 und
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Liegt eine Willenserklärung auch bei einer Gefälligkeit vor? Wonach ist zu differenzieren?
#
#  Antwort:
# Die Entscheidungsfragen sind in der Anlage 1.
#
# Die Klägerin verlangt von dem Beklagten die Rückzahlung eines Darlehens, das sie im Jahr 2014 aufgenommen hat und dessen Zinsbindungen zum Zeitpunkt des Vertragsabschlusses bis Ende Juni 2039 liefen (Anlagen K5-K7). Der Beklagte warb mit einem „Zeitraumgaranten“ für den Fall, dass sich ein Wertverlust ergibt oder es an Liquidität fehlt; dies soll dann durch einen Ausgleichsansprüche ersetzt werden. Das Gericht geht davon aus, dass zwischen den Parteien keinerlei Vereinbarungen über diese Garantiestellung getroffen wurden. Im Rahmen dieser Rechtshandlung wurde ihr vom Beklagten am 6./8. Juli 2014 ein Formularangebot zur Aufnahme eines Darlehensbetrages übersendet, welches unter anderem ua. enthielt: „Ich bin mir bewusst gewesen, daß ich hiermit meine Unbedingtheitszusage abgegeben habe.“ Mit Schreiben ihres Prozessbevollmächtigten vom 10. September 2019 forderte die Klägerin den Beklagten insoweit auf, ihre Erfüllungskonditionen zurückzuweisen bzw., falls nicht, ihren Vorschussbetrag nach § 3 Absatz 2 Satz 2 Nrn. 1 – 3 HWG iVm Artikel 2 Buchstabe a) EGBGB sowie §§ 355 ff. BGB herauszugeben. Dieser
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Definieren Sie Handlungswille, Erklärungsbewusstsein und Geschäftswille!
#
#  Antwort:
#
#
# Handlungs- oder Willensfähigkeit ist die Fähigkeit des Menschen zur eigenverantwortlichen Entscheidungen. Die Möglichkeit der Selbstbestimmtheit wird durch das Vorliegen einer psychischen Störung eingeschränkt (vgl.: BGH NJW 2013, 957). Der Tatrichter hat bei seiner Prüfung zu berücksichtigen, dass es sich um eine Rechtsfrage handelt; er muss daher nicht zwingend auf den medizinisch/psychiatrischer Sachkunde abhängig machen können. Es genügten vielmehr auch Indiziien für ein fehlgeschlagenes Versuch von Widerstand gegen einen anderen als dem Geistesgesundheitsschädlichen Einfluss bzw. eines Verhaltens aus einem krankhaften Zustand heraus. Dabei kann aber nur dann davon ausgegangen werden, wenn diese Umstände so deutliche Ausdruck gefunden haben, wie dies in § 64 Satz 1 Nrn. 1 bis 8 StGB voraussetzt. Das Gericht darf dabei keine unzulässige Beweislastumkehr zugunsten des Angelegenen verlangt wissen. Vielmehr sind alle relevanten Geschehnisse im Rahmen der Urteilsermittlung festzulegen und gegeneinander abzugewichten. Eine solche Abgrenzung zwischen normalem und pathologischem Verhalten lässt sich allerdings oftmals erst nach Einschätzung aller maßgebenden tatsächlicher Umstände treffen. Dies bedeute jedoch keinesfalls, dass man zunächst lediglich anhand der Symptome suchen soll, ob
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Maßstäbe zur Auslegung einer Willenserklärung gibt es, wo sind diese normiert und in welchem Verhältnis stehen sie zueinander?
#
#  Antwort:
# Die Entscheidungsfindung im Rahmen der Rechtsanwaltschaft ist eine wesentliche Kompetenz des Anwaltberufs. Sie erfordert die Fähigkeit zu eigenverantwortlicher Bewertung von Sach- oder Streitfragen unter Berücksichtigung aller relevanten Umstände (vgl. BGHZ 189, 205 = NJW 2013, 467 Rn. 1). Der Senat hat sich mit dieser Problematik bereits intensiv auseinandergesetzt; insbesondere haben wir uns auch schon mehrfach damit beschäftigt, wie einzelne Regelungen aus dem Bereich der Zivilprozessordnung auf den Fall eines Mandatswechsels anwendbar sein können bzw., ob dies überhaupt sinnvolle Ergebnisse liefert (Senatsbeschluss vom 18. Januar 2017 - OLGR Frankfurt am Main 2017, 101 f.). Insbesondere kann man nicht ohne weiteres davon ausgehen, dass das Gesetz für jede Situation einen bestimmten Weg vorgegeben habe. Vielmehr muss stets geprüft werden, was nach Lage der Dinge geboten erscheint. Dies gilt umso mehr als bei einem Wechsel zwischen zwei Parteien derselben Sache vor Gerichten verschiedener Ordnungsgemäßheitsrechte. So liegt hier der Fall, da Gegenstand sowohl des hiesigen Beschwerdeverfahrens als auch dessen Vorlage zum Bundesgerichtshof die Beurteilung darüber steht, wer berechtigterweise tätig wird könnte, wenn die Klägerseite ihre bisherige
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wann wird eine Willenserklärung wirksam? Welche Überlegung liegt dieser Regelung zugrunde?
#
#  Antwort:
# Die Entscheidungsfragen sind in der Prüfung zu behandeln. 1) Eine Erbschaftsquote von einem Drittel ist nach § 2034 BGB nur dann eröffnet, wenn die Nachlassgläubigerinnen und - glaubliche Personen den Anteil des Miterben auf einen Betrag berechnen können (von Oefele/Winkler-Schmidt, Rpfleger 69 [2005], S. 78). Dieser Berechnungsmethode hat das Bundesverwaltungsgericht mit Urteil vom 19. Juni 2008 – Az.: V C 10.07 –, nicht abschließend geklärt, gefolgt. Das Oberlandesgericht Frankfurt am Main hält diese Rechtsprechung für unzutriffig; es sieht sich angesichts einer Gesetzesbegründung aus dem Jahre 1957 gehalten, dies anders als bisher entsprechen zu wollen. Es vertritt nunmehr die Auffassung, dass auch bei Vorliegen eines schriftlichen Testamentes ein Vergleich zwischen dessen Inhalt und dem tatsächlich vorhandenen Vermögensbestand zur Ermittlung der Quote möglich sei. Denn im Falle fehlender Angaben über bestimmtes Grundstück oder sonstige Gegenstand muss davon ausgegangen werden, dass kein solcher Bestand existiert. Der Senat teilt diese Meinung nicht. Sie beruft sich darauf, dass die gesetzliche Formulierung „der Anteil“ durchaus mehrdeutig sein könne. Diese Ausführungen lassen aber außer acht, dass die Norm gerade keine Aussage zum Umfang
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wie wird der Anfechtungsgegner in seinem Vertrauen auf den Bestand des Rechtsgeschäfts geschützt?
#
#  Antwort:
# Die Entscheidung erfolgt nach billigem Ermessen. Der Senat hat die Berufungen gegen das Urteil des Landgerichts Hamburg vom 14.06.2018, Az.: 317 OH 5/17 (Kartell), gemäß § 9 Absatz 1 Satz 1 Nr. 1 GWBG zugelassen und sie mit Beschluss vom heutigen Tattag zurückgewiesen. I. Das landgerichtliche Urteil ist rechtskräftig seit dem 14. Juni 2018; es wurde am selben Tag verkündet sowie an diesem Tag im elektronischen Bundesanzeiger veröffentlicht. II. Zur Begründung seiner Zulassungsentscheide-nung nimmt der Senat Bezug auf seinen Hinweisbeschluß vom 14. November 2018. III. Mit ihrer jeweiligen Berufungsbegründung haben sich alle Parteien zu ihren erstinstanzlichen Ausführungen geäußert. IV. Nach Auffassung des Senats sind keine neuen Gesichtspunkte eingeführt worden oder sonstige Gründe ersichtlich, aus denen eine andere Beurteilung als durch das angefochtene Urteil geboten sein könnte. V. Es besteht keinerlei Grund für ein Absehen von einer Kostenentscheidung. VI. Eine Nebenforderung war nicht festzusetzen.
#
#
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wie unterscheidet man Erklärungs- und Inhaltsirrtum?
#
#  Antwort:
# Die Entscheidung ist nicht anfechtbar. 1.) Der Antrag des Klägers auf Bewilligung von Prozesskostenhilfebedingungen für das Berufungsverfahren wird zurückgewiesen, weil die Rechtsmittelbelehrung in der angefochtenen Kostengrundentscheidung den gesetzlichen Vorgaben entspricht (§ 567 Absatz ZPO). a) Nach § 308 Nr. 2 Satz 4 ZPO muss eine gerade im Rahmen einer Vergleichsvereinbarung erteilten Belehrung über die Möglichkeit eines Rücktrittes aus dem Vergleich nach Maßgabe dieser Norm formuliert sein; dies gilt auch dann, wenn es sich um einen Hinweis handelt, dass ein solcher Rücktritt möglicherweise unvertretbare Folgen haben könnte oder gar zu einem Schaden führen würde. Eine etwaige Unrichtigkeit kann daher nur durch Auslegung geklärt werden können. Dabei kommt es darauf an, wie der Empfangsbereite verstehen musste. Dieser hat allerdings keinen eigenständigen Beurteilungsspielraums hinsichtlich seiner rechtlichen Einschätzung. Es genügt vielmehr bereits die objektiv zutreffe Formulierung, sofern sie vom Adressaten dahingehend interpretierter worden war, was mit ihr gemeint gewesen sei. Ein Irrtum liegt vor, soweit zwischen ihm und seinem Willensbild keine Übereinstimmung besteht. b) Danach fehlte hier schon am Vorliegen irreführnder Angaben zum Zeitpunkt ihrer Abgabe
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist eine Täuschung?
#
#  Antwort:
# Die Entscheidungsfindung im Rahmen der Auslegung des § 138 Abs. 2 ZPO richtet sich nach den Grundsätzen, die für das Verständnis von Gesetzes- und Rechtsbegriffen gelten (vgl. BGHZ 46, 75; OLGR Frankfurt am Main 9/07). Der Wortlaut einer Vorschrift kann nur ein Indiz sein, um deren Inhalt zu bestimmt oder auszulegen. Dabei sind auch Sinn und Zweck sowie systematischer Kontext heranzuziehen. Eine isolierte Betrachtung eines Begriffs lässt seine tatsächliche Anwendbarkeit nicht erkennen. Es kommt vielmehr auf einen objektiven Maßstab an, wobei es unerheblich ist, ob dem Tatrichter bei seiner Beurteilung bewusste Vorstellungen zugrunde liegend waren. Das Gericht muss lediglich in einem Fall wie diesem davon ausgehen können, dass der Kläger mit seinem Sachverhalten zumindest vorgetaucht hat. Dieses Ergebnis wird durch weitere Umstände gestützt. So handelt der Kläger selbst sofort nach Ablehnung seines ersten Prospektantrags vom 1./2. Juni 2006 gegenüber Herrn Dr. K... . Nachdem dieser ihm zunächst noch Gelegenheit gegeben hatte, seinen Antrag neu zu stellen, schickt ihn sodann per EMail vom selben Tag unter Hinweis darauf, „dass ich mir keinen anderen Aufwand als bisher machen will“, zur Rücksendung des neuen Prospekte. Auch dies spricht dafür, dass der Kläger bereits damals keine
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Reicht das bloße Erkennen eines Irrtums für eine Aufklärungspflicht aus?
#
#  Antwort:
# Die Klägerin ist die Wohnungs- und Teileigentümergemeinschaft der B. Straße in H.. Sie nimmt den Verwalter, Herrn C., auf Schadensersatz wegen behaupteter Pflichtverletzungen im Zusammenhang mit dem Ausbau des Gemeindestraßenzuges vor Gericht in Anspruch (Klageantrag zu 1). Der Verwaltet hat sich darauf berufen, dass er nicht verpflichtet gewesen sei, einen von ihm eingeholten Gutachtenentwurfs anzufertigen oder ein solches zur Kenntnis nehmen lassen; dies wäre auch ungeachtet einer etwa bestehenden Pflichtverletzung keinesfalls kausal dafür geworden, dass es zum Bauplanänderungsproblem gekommen seien. Das Landgericht Frankfurt am Main – Einzelrichter - hat durch Beschluss vom heutzutage datiertem Urteil festgestellt, dass die Beratungskosten als notwendige Kosten nach § 20 Abs. 3 WEG erstattungsfähig sind. Zur Entscheidung über die sofortige weitere Beschwerde wird entsprechend §§ 45a FGG iVm. Nr. 67 Satz 8 RPflG abgetrennet.
#
# Die zulassenden Voraussetzungen gemäß § 9 a Abs. 2 FamFG liegen insoweit vor wie folgt: Es handelt sich um eine grundsätzliche rechtliche Fragestellung, deren Beantwortung allerdings nur dann klarstellend sein kann, wenn man zunächst davon ausgeht, dass bereits jetzt hinreichende tatsächlicher Vort
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist die Anfechtungserklärung?
#
#  Antwort:
# Die Entscheidungsformel des Urkundsnotars muss sich auf den Inhalt der Eröffnungsbeschlussfassungen und nicht nur darauf beschränken, dass eine Beschlussempfangnahme erfolgt sei. Der Senat hat mit dem angefochtenen Beschluß vom 14.09.2017 (Blatt 35 f.) festgestellt, daß das amtliche Zeugnis über die Eintragung einer Auflösung eines Gesellschaftsvertrages in Abteilung III Nr. 68/Auflösen von GbR-Gesellschaftern im Handelsregister eingetragen worden seien; zudem wurde ein Kostenansatz für einen Vermerksprotokollerlass ausgesetzt. Hiergegen richtet sich die sofortige weitere Beschwerde der Beteiligten zu Ziffer I., welche sie damit begründet, es fehle an einem wirksamen Amtsblattereintrag nach §§ 1 Abs. 1 Sätze 1 bis 3 FamFG iVm Artikel II Nummer IV Buchstabe a) EGBGB sowie bei dessen Vorliegen auch an einer ordentlichen Behandlung durch den Notar gemäß §§ 1 Abs. 1 Satz 1 FamFG iVm §§ 13, 14 RPflG. Wegen weiterer Einzelheiten wird Bezuge genommen auf Blatt 40 - 42 d. A.. Das Rechtsmittel führt zur Aufhebung des vorgenannten Beschlusses. Es kann offengelassen bleiben, ob vorliegend bereits keinerlei rechtliches Gehör gewährt werden
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wann liegt eine sog. Fehleridentität vor? Welche Auswirkung hat diese auf das Erfüllungsgeschäft?
#
#  Antwort:
# Die Entscheidungen des BGH vom 10. Juni und 23. September 2015 (VIII ZR 4/15) sind zu berücksichtigen, ebenso die Rechtsprechung der Oberlandesgerichte Frankfurt am Main sowie München I zum gleichen Thema aus dem Jahr 2016.
#
# Die Klägerin verlangt von den Beklagten Schadensersatz wegen einer fehlgeleiteten Kapitalanlage in Form eines Fonds-Konzepts mit einem Gesamtvolumen von ca. € 78 Mio., welches sie im Jahre 2009 erwarb. Der Anlegermodell ist ein sogenanntes „Splittingsmodell“, bei dessen Realisierung es zur Verteilung der Einnahmen zwischen verschiedenen Unternehmen kommt; dies geschieht über einen so genannten Splittergesellschaftsbeschluss nach § 3a Abs. 1 Nrn. 1 bis 3 Aktiengesetz i. V. m. Artikel 1 Buchstabe a der Richtlinie 2007/44/EWG des Europäischen Parlaments und des Rates vom 5. Juli 2007 betr. kapitalsuchende Gesellschaften. Das Konzepthandbuch entwickelte Herr Dr. H.. Dieser war auch als Prospektherausgeber tätig gewesen. Im Rahmen seiner Tätigkeit für andere Kunden hatte sich dieser bereits mehrere Male erfolgreich um die Aufnahme seines Modells bemühen lassen. In diesem Fall hatten seine Mandanten ihm gegenüber versprochen, dass keine weiteren Einwendungen erhoben würden. Auch sollte ke
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Bedürfen Rechtsgeschäfte einer besonderen Form?
#
#  Antwort:
# Die Entscheidung ist nicht anfechtbar. 1.) Der Antrag des Klägers auf Bewilligung von Prozesskostenhilfebedingungen wird zurückgewiesen, weil die Voraussetzung für eine Gewährung der beantragen Zahlungs- und Auslagenbedienungen nach §§ 2 Absatz , 3 Nr. 4 PKHG LSA (juris) bzw. §§ 567 ff., 98 Satz 2 ZPO iVm dem Beschlussverfahrensgesetz vom 02. Dezember 2004 - GBl. I/S.-Darst. S. ./. BtDrWrtKostlG - in Verbindung mit den Vorschriften über das Kostenrecht im Familiengerichtsverfahren gemäß Artikel II des Gesetzes zur Neuregelung kostenrechtlicher Regelungen bei Gerichtskonflikten zwischen Bund und Land sowie beim Bundesgerichthof vom 23. Juli 2004 –BGBl.I/S..-. /Bundesjustizmodernisierungsgesetz–(nachfolgend „PKHGBL“), wonach es sich um ein gerichtliches Verfahren handelt, vorliegend gegeben sind. aa.) Nach Auffassung des Senats kann auch ausnahmsweise dann, wenn keine Partei einen eigenständigen Begehren geltend macht oder kein eigener Streit entsteht, aber lediglich durch Erledigungserklärung eines Teils des streitbefangenen Lebensbereiches zu einem Zeitpunkt bis zum Schluss der letzten Tatsacheninstanz erkannt werden soll, dass nur noch ein Teilstre
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Funktionen hat die notarielle Beurkundung?
#
#  Antwort:
# Die Entscheidungsfragen sind in der Anlage 1 zu diesem Beschluss enthalten. Der Senat ist gemäß § 2 Absatz 3 Satz 4 Nr. 5, Absatz 6 und 7 des Gesetzes über das Verfahren bei den Oberlandesgerichten (VerfG) zuständig für diese Entscheidungen; er entschließt sich durch einen Einzelrichter nach Maßgabe von Artikel II Section I Nummer III Buchstaben a bis d dieses Geschäftsverteilungsplans vom 08. Dezember 2019. Zur Begründung wird auf Blatt 1 ff., 10 ff. sowie 13 ff. dieser Akten verwiesen.
#
# ## A. Zulässigkeit
#
# Die Voraussetzungen einer Auslegungskompetenz liegen vor. Nach dem Wortlaut des Notariatsgesetztes kann eine Regelungslücke nur dann bestehen, wenn eindeutige Vorschriften fehlen oder unklare Bestimmungen gegeben sein sollten. Eine solche Unbestimtheit liegt hier nicht vor. Es handelt sich um keine offene Rechtsnorm im Sinne eines „Raumes“ zur eigenständigen Interpretation. Das Gericht muss vielmehr lediglich zwischen mehreren möglicherweise richtiger Ergebnissen wählen. Dieser Fall stellt aber keinen Lückenschluss dar. Auch aus systematischen Gründen kommt es daher nicht zum Ausschlag gegenüber anderen Norminterpretationsmöglichkeiten. Denn auch insoweit gilt dasselbe wie oben ausgeführt. Schließlich spricht selbst der Zweck des Notariates als öffentliche Ur
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Wann liegt ein gesetzliches Verbot i. S. d. § 134 BGB vor?
#
#  Antwort:
# Die Entscheidung muss mit Gründen versehen sein, die sich auf den Gesetzeswortlaut und/oder das Regelungsgefüge stützen lassen (vgl.: OLG Frankfurt am Main, Beschluss vom 20. April 2017 - 6 UF 589/16). Der Antrag des Klägers wird zurückgewiesen. I. Mit der angefochtenen Kostenentscheidung hat das Amtsgericht dem Kläger nach Erledigungserklärungen im Hinblick darauf auferlegt, anteilige Gerichtskostenvorschusspauschalen in Höhe von jeweils € 1.000,- zu zahlen; insoweit ist er unterlegener Partei geworden. Hiergegen wendet sich der Kläger mit seinem Rechtsmittel. II. Das gemäß Artikel 111 Absatz 1 FGG-RG statthafte sowie formgerecht eingelegt und innerhalb der bis zum heutigen Tages verlängerten Fristen auch sonst rechtzeitig erhobene Rechtsmittel führt zur Zurückweisung seines Begehrens als unzulässiges Ablehnungsgesuch gegen Richter oder Dienstbeamten. Gemäß Ziffer III Nr. 1 Buchstabe a) RPflG sind bei einer gerichtlichen Entscheidung über eine Kostenfrage nur solche Personen ausgeschlossen, deren persönliche Unabhängigkeit durch ihre Stellung besonders gefährdet erscheint. Dies gilt nicht für alle richterlich entschiedenen Streitsachen, vielmehr kommt es hierzu maßgebend auf die konkrete Ausgestaltung eines Ein
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Welche Voraussetzungen müssen für eine Teilnichtigkeit nach § 139 BGB vorliegen?
#
#  Antwort:
# Die Entscheidung ist rechtskräftig.
#
# Die Klägerin verlangt von der Beklagten die Zahlung eines Schadensersatzes wegen einer behaupteten fehlerhaften Beratungsleitung im Rahmen des Erwerbs und Verkaufs zweier Grundstücke in A-Stadt, Straße2 (Grundbuch Blatt …). Der Antrag auf Bewilligung von Prozesskostenhilfe wurde mit Beschluss vom 08. März 2017 zurückgewiesen; hiergegen wendet sich das Rechtmittel der sofortigen Beschwerde gemäß Eingangsschriftsatz vom 15. Mai 2017. Das Gericht hat den Parteien Gelegenheit zur Stellungnahme gegeben. Es wird darauf hingewiesen, dass es an einem zulässigerweise eingereichten Einspruch gegen diesen Beschluss gefehlt haben dürfte. Eine solcher war nicht innerhalb der gesetzlichen Notfristen erfolgt. Nachdem auch keine Kostenerinnerung erhoben worden ist, kann davon ausgegangen werden, dass diese Möglichkeit ausgeschlossen sein könnte oder jedenfalls keinen Sinn mehr machen sollte. Im Übrigen besteht ein weiterer Hinderungsgrund zu dem angefochtenen Beschlusse. Diesem liegt nämlich bereits eine unrichtige Sachbehandlung durch das Amtsgericht zugrunde. Denn bei dieser Beurteilung handelt es sich um einen Fall der Nichteinschätzung bzw. Fehlbewertung der tatsächlich maßgebenden Umstände. Hierzu gehört insbesondere die Tatsache, dass die
#
#  ###########################
# Frage:
# Bitte beantworte folgende juristische Frage: Was ist ein Vertrag?
#
#  Antwort:
# ...
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Muss ein Rechtspfleger nach Anbringung eines Ablehnungsgesuchs zumindest einen Termin zur Verkündung einer Entscheidung anberaumen? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
#
#
# Der Senat für Familiensachen des Oberlandesgerichts Frankfurt am Main entscheidet in der Beschwerdeinstanz gemäß §§ 120 Abs. 3, 58 ff., 64 Satz 1 und 7 Nr. 9 RPflG durch den Einzelrichter (vgl. Bt-Drucksache 1/10; OLGR Hamm 2009, 1). Die sofortige weitere Beschwerde ist nicht statthaft (OLG Stuttgart NZFamR 2009, 101 m. w. Nachweisen aus Literatur und Praxis), weil die angefochtene Entscheidung keine Kostenentscheidung enthält (BGH FGPrax 2009, 185 = ZKJ 2009, 185) . Der Gegenstandswert wird auf bis zu € 1.000 festgesetzt. I. Das Amtsgericht hat dem Betroffenen eine Unterhaltsverpflichtung gegenüber seiner Ehegattin auferlegt sowie ihm unter anderem Aufwendungenersatz zugemutet. Hiergegen richtet sich seine Erinnerung vom 15. Juni 2009. Mit Schreiben seines Bevollmächtigten vom selben Tag beantragte er das Absehen von der Durchführung eines gerichtlichen Hauptsitzes bzw. dessen Verschiebung um zwei Wochen ab dem 29. Juli 2009. Dieser Bitte kam es im Rahmen der weiterhin laufenden Hauptverhandlung teilweise statt. Im Übrigen wurde über seinen Vorschlag hinaus - wie auch
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Wird die Verkündung einer Entscheidung (z.B. Zuschlag) erst vorgenommen, wenn das Befangenheitsgesuch erledigt ist? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# und begründe Ihre Auswahlentscheidung. 1.) Die Antragstellerinnen zu 2), …., beantragen: Der Senat wird verpflichtet festzustellen, dass der Beschluss des Landgerichts Hamburg vom 09. Februar 2018 über den Kostenfestsetzungsbeschwerdeantrag nichtig sei; hilfsweise für den Fall eines unbegründeten Nichtigerlöschens dieses Beschlusses durch eine andere Kammer des Oberlandesgerichts in gleicher Sache aufzuheben bzw. abändernd darüber neu entschieden werden sollte, ob dem Rechtsmittel gegen den angefochtenen Kostenerstattungs-/Kostenausgleichsbeschluss stattzugeben wäre. Im Übrigen bleibt es bei der Zurückweisung des Gesamten als unzulässiges Rechtsmittel. Das Gericht hat am 30. Januar 2017 einen Teilvergleich geschlossen, nachdem sich die Parteien im Hauptsachenrechtsstreit übereingekommen waren, soweit sie streiten haben. In diesem Teilvergleich wurde geregelt, dass „die Klägerin“ anteilige außerprozessual entstandene notwendige Aufwendungen iHv € 456,- sowie vorgerichtliche Mahngebühren von insg. € 10,-- nebst gesetzlicher Mehrwertsteuer trage.“ Mit Schriftsatz ihres Prozessbevollmächtigten vom 14. März 2017 machte die Antragstellerin unter Bezugnahme auf § 1 Abs. 1 Nrn. 1 bis 3 RV
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Muss eine sofortige Beschwerde innerhalb einer Notfrist von zwei Wochen nach Zustellung des Beschlusses eingelegt werden? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# und erläutere Ihre Entscheidung.
#
# 1) Die Antragsteller haben die Kosten der Verfahren zu tragen, soweit sie unterliegen (§ 269 Abs 3 Satz 2 FamFG). Der Senat hat den Streitgegnern keine notwendigen Auslagen auferlegt; diese sind vielmehr dem Staat als Träger öffentlicher Aufgaben aufzuerlegen (vgl. BVerfGE 78, 54/60 f.; OLGR Frankfurt am Main-Oberhessische Rechtspflegerkammer 2009, 101 = NZV 2009, 511 m. w. Nachweisen aus Literatur und Praxis), weil es sich bei ihnen um Behörden handelt, deren Tätigkeit im Interesse aller Daseinsgemeinschaft gelebt wird. Dies gilt auch für das Land Hessen in seiner Eigenschaft als Gesetzgebungsgewalt sowie für dessen Ministeriumsbeauftrage wie hier das hessischen Justizministerium bzw. seine Unterorganisation - die Staatsanwaltschaft Gießen – . Für dieselben Gründe ist davon abgesehen worden, dass ein Teilbetrag an Gerichtskostengeld festsetzt wurde. Das Feststellungsinteresses steht nicht entgegen: § 269 III Nr. 2 FGG schließt nur einen Erfolgseintritt gegenüber einem Dritten aus, aber keinen solchen vor Einrichtungen, denen durch ihre gesellschaftliche Position besondere Pflichten obliegen können. So liegt der Fall hier. Auch wenn man zugunsten eines anderen Grundrechtsverhältnis versteht
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Beginnt die Frist für die Einlegung einer sofortigen Beschwerde mit der Zustellung des Beschlusses? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# und erläutere Ihre Entscheidung.
#
# 1) Die Antragsteller haben am 20. März 2019 einen Eilantrag gestellt, den das Verwaltungsgericht durch Beschlüsse vom 30. April 2018 (Az.: OVG .../4 B 567/18), vom 10. Mai 2018 (OVG … /4 B 567/18) sowie vom 10. Juli 2018 (OVG … /4 B 567/18) zurückgewiesen hat; diese Beschlüsse sind dem Prozessbevollmächtigten der Antragsgegnerinnen zugestellt worden. Mit Schriftsatz ihres Bevollmächtigten vom 10. August 2018 - eingegangen beim Oberverwaltungsgericht am selben Tag – haben sie gegen alle drei vorgenannten Beschlüsse „sofortige“ Beschwerden erhoben. Das Oberverwaltungsgericht ist davon ausgegangen, dass es sich bei diesen Rechtsmitteln um unstatthafte Nebenforderungen handelt, weil eine Statthaftigkeit nur dann in Betracht kommt, wenn ein solches Rechtsmittel innerhalb eines Monats nach Kenntnis von der angefochtenen gerichtlichen Maßnahme geltend gemacht wird. Der Senat hätte daher erst ab September 2018 über deren Eröffnung entscheiden können. Dieser Auffassung schließt sich auch der Hinweis auf § 147 Abs. 1 VwGO an: Danach muss binnen zwei Woc
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Führt das Versäumnis der Beschwerdefrist zur Unzulässigkeit der Beschwerde? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
#
#
# 1. Die sofortige weitere Beschwerde des Angelegenen gegen den Kostenfestsetzungsbeschluss vom 20. März 2019 wird als unbegründet verworfen, soweit die Entscheidung über eine Erstattungsverpflichtung nicht getroffen wurde; im Übrigen ist sie zwar statthaft und auch sonst in verfahrensrechtlicher Hinsicht nicht zu beanstanden (§ 46 Absatz 3 Satz 5 OWiG), jedoch begründet es keinen Verstoß gegen § 78 GKG iVm Artikel 103 Absatz 1 Grundgesetz, dass dem Rechtsmittelführer ein Mangel an Sachkunde angelastet werden kann: Der Senat hat bereits entschieden, dass sich aus einer fehlerhaften Ausführungen von Gerichten keine Pflicht ergibt, diese Fehlernachweise durch einen eigenständig gefassten neuen Tenor aufzuheben [vgl. BVerfGE 117, 1 ff., Rn. 1]. Dies gilt erst recht für die Frage eines möglich erscheinenden Gehörsrügenfehlens nach § 32d StPO bzw. einem etwa vorliegend gegebenen Ermessensspielraum bei der Feststellung der Erfolgs-/Mindereignisse gemäß Nr. 4100 VV RVG. Dass dieses Vorbringen hier letztlich ohne Belang war, steht außer Streit. Es kommt hinzu, dass der angefochtene Kostenerstattungsbetrag lediglich um ca. € 10 beträgt - was wohl nur weniger
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Wird eine verspätete sofortige Beschwerde gemäß § 572 Abs. 2 ZPO als unzulässig verworfen? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# (Rn.1)
#
# Die Entscheidung ist nicht anfechtbar. Die Verspätungsrüge der Beklagten vom 09. März 2018 gegen den Kostenfestsetzungsbeschluss des Amtsgerichts Hamburg-Blankenburg, Az.: … wird zurückgewiesen. I. Der Kläger hat die Beklagte auf Schadensersatz in Anspruch genommen wegen eines Verkehrsunfalls am ... . Mit Urteil vom 30. Januar 2014 wurde das Landesarbeitsgericht Hamburg zu Gunsten des Klägers entschieden und ihm ein Betrag von € 6.000,- zugesprochen. Das Berufungsverfahren vor dem LAG war beendet worden durch einen Teilanerkenntnisurteil sowie einem Schlussurteil nach Beendigung einer mündlichen Gütetermin im Rahmen eines gerichtlich angeordneten Mediationsversuchs. Nachdem sich der Prozessbevollmächtigte für den Kläger ausweislich seiner Unterschriftszeichenkarte seit Oktober 2014 bei Gerichten registriert hatte, beantragt er unter Vorlage seines Rechtsanwaltescheins Nr..../... beim AG Blankenburg die Feststellung der Erledigungskostenpflichtigkeit hinsichtlich aller außergerichtlicher Auslagen einschließlich Postkostenzuschlägen nebst Erstattungsfähigkeit sämtlicher notwendigen Aufwendungen zur Durchführung dieses Mandats. Hierzu legt er u. a. seine Honorarkalkulation über insgesamt € 1.114,-- vor. Diesem Kostenfestsetzungsantrag w
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Ist der Haftvollzug nach § 802h ZPO nach zwei Jahren nicht mehr zulässig? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
#
#
# 1. Die Frage, ob die Vorschrift des § 802 h Absatz 3 Satz 4 StGB (jetzt: §§ 67c ff., 95e FamFG) auch für den Fall gilt, dass das Strafurteil bereits vor Ablauf von drei Monaten erlassen worden ist und somit eine Verlängerungsmöglichkeit gemäß § 802 b Nrn. 1 bis 3 StGB ausgeschlossen war, wird in Rechtsprechungs-und Literatur unterschiedlich beantwortet.(Rn.1)
#          2. Nach einer Ansicht kann ein Urkundenverbot nur dann angeordnet werden, wenn es zu einem Zeitpunkt eingeführt wurde, als noch keine Entscheidungen über einen Freiheitsentziehungsvorbehalt getroffen wurden; dieses Erfordernis würde durch eine rückblickende Einführung eines solchen Vorbehalts verletzt.(Rn.2)
#          Der Senat schließt sich dieser Meinung an. Eine andere Methode zur Beendigung des Untersuchungshaftvollzugs besteht im Gesetz nicht.(Rn.2)
#         (Rn.3)
#           1.) Wenn man davon ausgehen will, dass bei dem hier maßgeblichen Tatzeitraum vom 1./2. Juni 2015 bis zum 1/2 Juli 2015 aufgrund der Regelung des Artikel 11 EMRK keinerlei Beschränkungen vorgesehen sind, so müsste diese Maßnahme schon wegen unangemessener Dauer gegenüber anderen Mitgliedstaaten Europas rechtswid
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Dürfen im Mahnverfahren offensichtlich unbegründete Haupt- und Nebenforderungen durch den Rechtspfleger zurückgewiesen werden? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# (Rn.1)
#
# Der Antrag des Schuldners auf Bewilligung von Prozesskostenhilfe für das Beschwerdeverfahren gegen die Kostengrundentscheidung in dem Urteil der 20. Zivilkammer - Einzelrichterin am Landgerichts Halle vom 30. Juni 2015 wird abgelehnt, da es an einer hinreichend erfolgsversprechenden Bemühungsanzeige fehlte. Der Senat hat bereits entschieden, dass ein Verstoß gegen § 94 Absatz 6 Satz 1 Nr. 7 VWGO nicht zu beanstanden ist, wenn sich aus einem rechtskräftigen Urteil keine Forderung mehr herauslesen lässt; dies gilt auch dann, wenn eine solche Forderung erst nach Erlass eines Versäumnisurteils begründet wurde (vgl. OLG Naumburg, Beschluss v. 8. April 2015 – 1 WF 1/15). Die Entscheidung über einen Rücknahmeantrag kann zwar grundlegend sein, sie stellt aber keinen eigenständig tragenden Grund zur Herabsetzung bzw. Aufhebung der titulierten Beträgen dar. Sie betrifft lediglich die Frage, ob diese noch bestehen bleiben sollten. Dieser Umfang muss bei jeder Behandlung dieser Fallgestaltung berücksichtigt werden. Es wäre also sinnlos gewesen, hierzu weitere Ausführungen vorzunehmen. Das gleichen gelten für die weiteren Gründe, warum die Klägerseite ihre Berufungsbeklagtes verpflicht
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Ist die Unterschrift des Einspruch Einlegenden entbehrlich, solange ersichtlich ist, wer den Einspruch eingelegt hat? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# (vgl. BGH NZV 2013, 457).
#
# Die Entscheidung ergeht gerichtsgebührenfrei; außergerichtliche Kosten werden nicht erstattet. Die Beschwerde wird als unzulässig verworfen. Der Antragsteller trug die Gerichtskosten und seine notwendigen Auslagen selbst. Außerdem wurde der Streitwert für das Verwaltungsverfahren auf € 689 festgesetzt. I. Mit Bescheiden vom 10./11. Juni 2014 ordnete der Landkreis A-Stadt gegenüber dem Antragsgegner an: „Ihnen wird untersagt, im Gebiet von … in einem Umfang von ca. 1 ha eine Windenergieanlage zu errichten.“ Hierauf legte dieser Widerspruch ein sowie einen Normenkontrollantrag beim Oberverwaltungsgericht vor. Nachdem sich herausgestellt hatte, dass es bei diesem Vorhaben um zwei Projekte handelte – eines am Standort H., einerseits, andererseits am Standort S.-Straße –, teilten beide Betroffenen ihre jeweilige Rechtsmittelbefassungen voneinander ab. Das Bundesministerium für Ernährung und Ländlicher Räume gab daraufhin bekannt, dass man davon ausgehe, dass diese beiden Bauvorhaben durch dieselben Planergänzungsbeschlüsse geregelt worden seien. Deshalb würden sie nunmehr zusammen behandeln müssen. Darum bat auch der Senat alle betreffen Partei dazu, bis zum nächsten Plenum Termine zur Erörterung ihrer Sachstand
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Kann das Gericht einen Antrag auf Hinzuziehung eines weiteren Sachverständigen ablehnen, wenn es durch die Anhörung des bereits bestellten Sachverständigen ausreichende eigene Sachkunde erlangt hat? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
# und begründe. 1) Die Entscheidungsformel ist unzureichend (§ 267 Absatz 4 Satz 3 StPO). Der Senat kann nicht feststellen, ob der Beschluss vom 08. März 2019 rechtsfehlerfrei getroffen wurde; eine Überprüfbarkeit scheitert an dem fehlenden Tenor im Sinne von § 54 Absätze 1 bis 3 JVEG iVm Artikel 103 GG. Eine Auslegung nach den Gründen kommt mangels hinreichender Bestimmtheit ebenfalls nicht in Betracht.(Rn.1)
#
#             Das Verwaltungsgericht Berlin wird gebeten, über die Zulässigkeit einer gerichtlichen Befangenheitsantrags gegenüber ihm zu entscheiden. I. Mit Schreiben seines Prozessbevollmächtigten vom 08. Februar 2019 beanstandete Herr A., ein Mitarbeiter des Landesamtes für Geoinformation und Landentwicklung Mecklenburg-Vorpommerns als sachbearbeitender Beamter bei der zuständigen Abteilung „Geodäsische Dienste“ beim Ministerium für Inneres und Sport Mecklenburg-Vorpommern, seine Teilnahme am Erörterungstermin vor dem Oberlandesgericht Rostock zum Aktenzeichen II OLGR 1/19 vormittwoch, da dieser Termin weder ordnungsgemäß geladen noch bekannt gegeben worden sei. Nachdem sich herausgestellt habe, dass dies falsch gewesen sein sollte, werde nunmehr klargestellt:
#
#  YES_NO:
# Unklar
#
#  ###########################
# Frage:
# Kann die Ablehnung eines Antrags auf Hinzuziehung eines weiteren Sachverständigen gerechtfertigt sein, wenn das Gericht dem ersten Gutachter nicht folgen will? Antworte mit 'Ja,' 'Nein,' oder 'Unklar'
#
#  Antwort:
#
#
# KORE628052019 ECLI:DE:BGH:2017:300417BVIIIZR2.17.0 BGH 8. Zivilsenat 20170430 VIII ZR 2/17 Beschluss § 411 Abs 6 S 1 Nr 1 Alt 1 ZPO vorgehend OLG Frankfurt, 14. November 2016, Az: 1 U 101/16 (A), Urteil DEU Bundesrepublik Deutschland Die Revision der Kläger gegen das Teilurteil des Oberlandesgerichts Frankfurt am Main - 1. Strafsenat für Handelssachen und Berufungs-Strafkammer I - vom 14. November 2016 wird als unzulässig verworfen; im Übrigen hat es seine Entscheidungen in den Rechtsmittelinstanzen zu Lasten der Kläger gehabt. Jeder Streithelfer trägt die ihm entstandenen notwendigen Auslagen selbst. Der Wert des Nebeninterventionsgegenstands beträgt bis einschließlich 30. April 2017 € 1.000,- ab diesem Zeitpunkt € 1.500.-. Von einer Festsetzung von Prozessgebühren gemäß §§ 11 RPflG i. V. m. Nrn. 1210 f., 1212 BRAGO aF sowie nach Maßgabe von Nr. 1210 BRAGO nF bedürfe es wegen der gesetzlichen Regelung über eine Gebührsfreiheit bei einem Ver
#
#  YES_NO:
# Unklar
#
#  ###########################
# FINISHED YES_NO
