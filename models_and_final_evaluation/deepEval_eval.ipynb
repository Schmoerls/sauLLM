# %%
# Dieses Notebook liest die DeepEval Evaluations .txt Dateien aus und berechnet die durchschnittliche Korrektheit
# Außerdem werden aus den Daten Grafiken erzeugt

# %%
import re

with open('/Users/schmorls/Desktop/psEval/deepeval_results/plainData-6500.txt', 'r') as file:
    content = file.read()

scores_strings = re.findall(r'score: (\d+\.\d+)', content)

scores = [float(score) for score in scores_strings]

print("Found: " + str(len(scores)) + " scores")
# Print the filtered scores
print(sum(scores) / 40)
# Out:
# Found: 40 scores
# 0.02534898852393464

# %%
plain_1000_score = 0.008931563155232015
plain_2000_score = 0.04200791072612373
plain_3000_score = 0.010752115237796749
plain_4000_score = 0.03402280239430354
plain_5000_score = 0.008825025322039208
plain_6500_score = 0.02534898852393464

# %%
import matplotlib.pyplot as plt

x_values = [1000, 2000, 3000, 4000, 5000, 6500]
y_values = [plain_1000_score, plain_2000_score, plain_3000_score, plain_4000_score, plain_5000_score, plain_6500_score,]

plt.plot(x_values, y_values, marker='o', linestyle='-', color='b', label="Float Values")

plt.xlabel("Training steps")
plt.ylabel("Correctness")
plt.title("Correctness of plain data training steps")

plt.show()

# %%
chat_gpt_score = 0.717649538359005
gptData_score = 0.12818017476360136
plainData_score = 0.02534898852393464
reinforcement_score = 0.008158834813850845
pretraining_score = 0.19619137642764234
mistral_base_score = 0.11989289018797271

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Configuration": ["ChatGpt", "MistralBase", "GptFinetuning", "PlainFinetuning", "Pretraining"],
    "Type": ["ChatGpt-Model", "MistralBase-Model", "ChatGptData-Finetuning-862", "PlainData-Finetuning-6500", "Continual-Pretraining-3451"],
    "Percentage": [
        chat_gpt_score, #ChatGpt
        mistral_base_score, #MistralBase
        gptData_score, #ChatGptData-Finetuning
        plainData_score, #PlainData-Finetuning  
        pretraining_score, #Pretraining 
    ],
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Configuration", y="Percentage", hue="Type")

plt.title("Deep Eval Correctness")
plt.xlabel("")
plt.ylabel("Percentage")
plt.legend(title="Type", bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %%
chat_gpt_score = 0.86
gptData_score = 0.18
plainData_score = 0.27
pretraining_score = 0.22
mistral_base_score = 0.18

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Configuration": ["ChatGpt", "MistralBase", "GptFinetuning", "PlainFinetuning", "Pretraining"],
    "Type": ["ChatGpt-Model", "MistralBase-Model", "ChatGptData-Finetuning-862", "PlainData-Finetuning-6500", "Continual-Pretraining-3451"],
    "Percentage": [
        chat_gpt_score, #ChatGpt
        mistral_base_score, #MistralBase
        gptData_score, #ChatGptData-Finetuning
        plainData_score, #PlainData-Finetuning  
        pretraining_score, #Pretraining 
    ],
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Configuration", y="Percentage", hue="Type")

plt.title("Manual Score")
plt.xlabel("")
plt.ylabel("Percentage")
plt.legend(title="Type", bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()
